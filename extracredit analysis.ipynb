# %% [markdown]
# # Test Summary
# - All 5 test cases have passed successfully.

# %% [markdown]
# ## Test Details

# %% [markdown]
# ### ' test_elasticnet_fit_predict_small_test'

# %%
import matplotlib.pyplot as plt

# Loss values for test_elasticnet_fit_predict_small_test
iterations_small = [1, 79]
loss_small = [0.8138483865698529, 0.18289415072034765]

plt.figure(figsize=(8, 5))
plt.plot(iterations_small, loss_small, marker='o', linestyle='-')
plt.title('Loss Over Iterations: test_elasticnet_fit_predict_small_test')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ' test_elasticnet_fit_predict_synthetic '

# %%
# Loss values for test_elasticnet_fit_predict_synthetic
iterations_synthetic = [1, 11]
loss_synthetic = [0.2480363628013885, 0.15761366407585842]

plt.figure(figsize=(8, 5))
plt.plot(iterations_synthetic, loss_synthetic, marker='o', linestyle='-', color='green')
plt.title('Loss Over Iterations: test_elasticnet_fit_predict_synthetic')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 'test_zero_variance_feature_small_test'

# %%
# Loss values for test_zero_variance_feature_small_test
iterations_zero_var_small = list(range(1, 3844, 100)) + [3843]
loss_zero_var_small = [
    0.8094484113101857,
    0.11348791098790559,
    0.11348833040128285,
    0.11348933734133358,
    0.11349012136059657,
    0.11349073179829143,
    0.11349120707945204,
    0.11349157712542976,
    0.11349186523489808,
    0.11349208954913978,
    0.11349226419335218,
    0.11349240016551848,
    0.11349250602862732,
    0.11349258844971517,
    0.11349265261960868,
    0.11349270257975852,
    0.11349274147672275,
    0.1134927717603117,
    0.11349279533786372,
    0.11349281369436352,
    0.11349282798596429,
    0.11349283911280197,
    0.11349284777568662,
    0.11349285452024059,
    0.11349285977126307,
    0.1134928638594851,
    0.11349286704240008,
    0.11349286952048149,
    0.11349287144980956,
    0.11349287295190173,
    0.11349287412136627,
    0.1134928750318612,
    0.1134928757407335,
    0.11349287629263102,
    0.11349287672231476,
    0.11349287705684807,
    0.11349287731730132,
    0.11349287752007904,
    0.11349287767795309,
    0.11349287873143073
]

plt.figure(figsize=(10, 6))
plt.plot(iterations_zero_var_small, loss_zero_var_small, marker='x', linestyle='-', color='red')
plt.title('Loss Over Iterations: test_zero_variance_feature_small_test')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### ' test_zero_variance_feature_synthetic'

# %%
# Loss values for test_zero_variance_feature_synthetic
iterations_zero_var_synthetic = list(range(1, 956, 100)) + [955]
loss_zero_var_synthetic = [
    0.7808703942509939,
    0.15893821461720334,
    0.15895228493760796,
    0.15896093020411556,
    0.15896616870017413,
    0.15896934255787273,
    0.15897126538213102,
    0.15897243024381283,
    0.15897313590885337,
    0.15897356338951335,
    0.1589747188811727
]

plt.figure(figsize=(10, 6))
plt.plot(iterations_zero_var_synthetic, loss_zero_var_synthetic, marker='s', linestyle='-', color='purple')
plt.title('Loss Over Iterations: test_zero_variance_feature_synthetic')
plt.xlabel('Iteration')
plt.ylabel('Loss')
plt.grid(True)
plt.show()

# %% [markdown]
# ### 'test_invalid_optimization_option_small_test'

# %% [markdown]
# - No iterative loss data available as this test checks for exception handling.

# %% [markdown]
# ### Conclusion
# - All test cases have passed without any issues, ensuring the robustness and reliability of the ElasticNetModel implementation.
